# %%
import matplotlib.pyplot as plt

# Data for Selection Sort
x_sel = [5, 10, 20, 50, 100, 500, 1000, 5000,10000,20000,30000,40000,50000]
y_sel = [5e-07,1.3e-06,2.2e-06,9.5e-06,3.08e-05,0.000627,0.0023517,0.0569425,0.217667,0.90598,1.97542,3.48149,5.37219]

# Data for Insertion Sort
x_ins = [5, 10, 20, 50, 100, 500, 1000, 5000,10000,20000,30000,40000,50000]
y_ins = [2e-07,5e-07,1.3e-06,4.5e-06,2.22e-05,0.0004893,0.0017502,0.0369939,0.146127,0.572828,1.25735,2.20588,3.51983]

# Data for Bubble Sort
x_bub = [5, 10, 20, 50, 100, 500, 1000, 5000,10000,20000,30000,40000,50000]
y_bub = [8e-07, 2.2e-06,2.6e-06, 1.45e-05, 6.66e-05, 0.001408, 0.0057132, 0.150659,0.585995,2.34572,5.23766,9.30433,22.0952]

# Plotting
plt.figure()
plt.plot(x_sel, y_sel, marker='o', linestyle='-', color='r', label='Selection Sort')
plt.plot(x_ins, y_ins, marker='o', linestyle='-', color='b', label='Insertion Sort')
plt.plot(x_bub, y_bub, marker='o', linestyle='-', color='g', label='Bubble Sort')

plt.xlabel('Input Array Sizes')
plt.ylabel('Runtime (secs)')
plt.title('Benchmark - Insertion, Selection, and Bubble Sorts')
plt.grid(True)
plt.legend()
plt.savefig('benchmark_sorting_algorithms.png')
plt.show()
